# %% [markdown]
# # Assignment 1
# ### Understanding Uncertainty
# ### Due 9/5

# %% [markdown]
# Bella Lu

# %% [markdown]
# 1. Create a new public repo on Github under your account. Include a readme file.
# 2. Clone it to your machine. Put this file into that repo.
# 3. Use the following function to download the example data for the course:

# %%
def download_data(force=False):
    """Download and extract course data from Zenodo."""
    import urllib.request, zipfile, os
    
    zip_path = 'data.zip'
    data_dir = 'data'
    
    if not os.path.exists(zip_path) or force:
        print("Downloading course data")
        urllib.request.urlretrieve(
            'https://zenodo.org/records/16954427/files/data.zip?download=1',
            zip_path
        )
        print("Download complete")
    else:
        print("Download file already exists")
        
    if not os.path.exists(data_dir) or force:
        print("Extracting data files...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir)
        print("Data extracted")
    else:
        print("Data directory already exists")

download_data()
# Out:
# ...
# Download complete
# Extracting data files...
# Data extracted

# %% [markdown]
# 4. Open one of the datasets using Pandas:
#     1. `ames_prices.csv`: Housing characteristics and prices
#     2. `college_completion.csv`: Public, nonprofit, and for-profit educational institutions, graduation rates, and financial aid
#     3. `ForeignGifts_edu.csv`: Monetary and in-kind transfers from foreign entities to U.S. educational institutions
#     4. `iowa.csv`: Liquor sales in Iowa, at the transaction level
#     5. `metabric.csv`: Cancer patient and outcome data
#     6. `mn_police_use_of_force.csv`: Records of physical altercations between Minnessota police and private citizens
#     7. `nhanes_data_17_18.csv`: National Health and Nutrition Examination Survey
#     8. `tuna.csv`: Yellowfin Tuna Genome (I don't recommend this one; it's just a sequence of G, C, A, T )
#     9. `va_procurement.csv`: Public spending by the state of Virginia

# %%
import pandas as pd

df = pd.read_csv('/Users/bellalu/DS 5030/DS5030UnderstandingUncertainty/data/ames_prices.csv')
df
# Out:
#       Order        PID  area   price  MS.SubClass MS.Zoning  Lot.Frontage  \
# 0         1  526301100  1656  215000           20        RL         141.0
# 1         2  526350040   896  105000           20        RH          80.0
# 2         3  526351010  1329  172000           20        RL          81.0
# 3         4  526353030  2110  244000           20        RL          93.0
# 4         5  527105010  1629  189900           60        RL          74.0
# ...     ...        ...   ...     ...          ...       ...           ...
# 2925   2926  923275080  1003  142500           80        RL          37.0
# 2926   2927  923276100   902  131000           20        RL           NaN
# 2927   2928  923400125   970  132000           85        RL          62.0
# 2928   2929  924100070  1389  170000           20        RL          77.0
# 2929   2930  924151050  2000  188000           60        RL          74.0
#
#       Lot.Area Street Alley  ... Screen.Porch Pool.Area Pool.QC  Fence  \
# ...

# %% [markdown]
# 5. Pick two or three variables and briefly analyze them
#     - Is it a categorical or numeric variable?
#     - How many missing values are there? (`df['var'].isna()` and `np.sum()`)
#     - If categorical, tabulate the values (`df['var'].value_counts()`) and if numeric, get a summary (`df['var'].describe()`)

# %% [markdown]
# The 'price' variable is a numeric variable. There are no missing values.

# %%
#price 
df['price'].isna().sum()
df['price'].describe()
# Out:
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: price, dtype: float64

# %% [markdown]
# The 'Street' variable is a categorical variable. There are no missing values.

# %%
df['Street'].isna().sum()
df['Street'].value_counts()
# Out:
# Street
# Pave    2918
# Grvl      12
# Name: count, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Order', 'PID', 'area', 'price', 'MS.SubClass', 'MS.Zoning',
#        'Lot.Frontage', 'Lot.Area', 'Street', 'Alley', 'Lot.Shape',
#        'Land.Contour', 'Utilities', 'Lot.Config', 'Land.Slope', 'Neighborhood',
#        'Condition.1', 'Condition.2', 'Bldg.Type', 'House.Style',
#        'Overall.Qual', 'Overall.Cond', 'Year.Built', 'Year.Remod.Add',
#        'Roof.Style', 'Roof.Matl', 'Exterior.1st', 'Exterior.2nd',
#        'Mas.Vnr.Type', 'Mas.Vnr.Area', 'Exter.Qual', 'Exter.Cond',
#        'Foundation', 'Bsmt.Qual', 'Bsmt.Cond', 'Bsmt.Exposure',
#        'BsmtFin.Type.1', 'BsmtFin.SF.1', 'BsmtFin.Type.2', 'BsmtFin.SF.2',
#        'Bsmt.Unf.SF', 'Total.Bsmt.SF', 'Heating', 'Heating.QC', 'Central.Air',
#        'Electrical', 'X1st.Flr.SF', 'X2nd.Flr.SF', 'Low.Qual.Fin.SF',
#        'Bsmt.Full.Bath', 'Bsmt.Half.Bath', 'Full.Bath', 'Half.Bath',
#        'Bedroom.AbvGr', 'Kitchen.AbvGr', 'Kitchen.Qual', 'TotRms.AbvGrd',
# ...

# %% [markdown]
# 6. What are some questions and prediction tools you could create using these data? Who would the stakeholder be for that prediction tool? What practical or ethical questions would it create? What other data would you want, that are not available in your data?

# %% [markdown]
# Using this data, you could be able to predict the sale price of a house based on certain requirements or features of the house using variables such as MS.Zoning, area, Overall Style, number of bedrooms, etc. The stakeholders for this tool could be real estate agents or those interested in buying a home. Some practical questions that could be applied are: Is this model accurate? What are the most important factors that influence the sale price of a house? Some ethical questions could be: Could this model introduce bias into the market to the detriment of buyers and sellers?
# Another idea would be to develop a model to predict the likelihood of a house to be bought using variables such as price, area, and order. The stakeholders for this tool would be real estate agencies. Some practical questions to consider are: Is this model accurate? What are the most important features in determining the likelihood of a house being bought? Some ethical questions could be: Could this model introduce discrimination through agencies unfairly penalizing towards certain homeowners?
#
# Other data that I would want to see is more about the area: what are the crime rates? What amenities are included close to the area? What are the renovation costs? If the house is sold - when was it sold and by who? What are the demographics of the buyer?

# %% [markdown]
# 7. Commit your work to the repo (`git commit -am 'Finish assignment'` at the command line, or use the Git panel in VS Code). Push your work back to Github and submit the link on Canvas in the assignment tab.
